# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("pizzas.csv")
df
# Out:
#     diametro  preco
# 0         20     50
# 1         22     55
# 2         24     60
# 3         20     50
# 4         22     55
# 5         24     60
# 6         26     65
# 7         28     70
# 8         30     75
# 9         32     80
# 10        34     85
# 11        36     90
# 12        38     95
# 13        40    100

# %%
df.describe()
# Out:
#         diametro       preco
# count  14.000000   14.000000
# mean   28.285714   70.714286
# std     6.787189   16.967972
# min    20.000000   50.000000
# 25%    22.500000   56.250000
# 50%    27.000000   67.500000
# 75%    33.500000   83.750000
# max    40.000000  100.000000

# %%
from sklearn import linear_model

modelo = linear_model.LinearRegression()
x = df[["diametro"]]
y = df[["preco"]]

modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.figure (figsize=(10,6))
sns.scatterplot(data=df, x= 'diametro', y= 'preco')
plt.grid()
plt.show()
